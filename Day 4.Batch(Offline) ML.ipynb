# %%
import numpy as np
from sklearn.linear_model import LinearRegression


x=np.array([[500],[1000],[1500],[2000],[2500]])
y=np.array([5,10,15,20,25])

model=LinearRegression()
model.fit(x,y)

new_house=np.array([[1800]])
predicted_price=model.predict(new_house)

print("New House Predicted Price",predicted_price[0],'in Lacks')
# Out:
# New House Predicted Price 18.0 in Lacks

# %%
x_new=np.array([[30000]])
y_new=np.array([30])

# Combine old + new data
X_updated = np.vstack((X, X_new))
y_updated = np.append(y, y_new)

# Retrain model (Batch Learning again)
model.fit(X_updated, y_updated)
