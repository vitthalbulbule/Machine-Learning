# %%
# Tensor is an like an data structure in machine learning used to store the Numerical data.
# Machine learning library like Tenserflow and pytorch is based on the Tensor , Tensor is most important factor in those libraryes
# Tenor Act as an container for storing the numerical data

# %%
import numpy as np

# %% [markdown]
# ## 0D Tensor (Scaler)

# %%
arr=np.array(10)
arr
# Out:
# array(10)

# %%
arr.ndim
# Out:
# 0

# %% [markdown]
# ## 1D Tensor(Vector)

# %%
d_arr=np.array([1,2,3,4,5])    # Its an 1D Tensor but 5D Vector (Element Present in the vector) )
d_arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
d_arr.ndim
# Out:
# 1

# %% [markdown]
# ## 2D Tensor (Matrix)

# %%
d_arr=np.array([[1,2,3],
               [4,5,6]])
d_arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
d_arr.ndim                # This is an 2D array or collection of vectors
# Out:
# 2

# %%
## 3D Tensor 

d_arr=np.array([[
    [1,2,3],[4,5,6]
],
   [ [6,7,8],[9,10,11]
               
               ] ])

# %%
d_arr
# Out:
# array([[[ 1,  2,  3],
#         [ 4,  5,  6]],
#
#        [[ 6,  7,  8],
#         [ 9, 10, 11]]])

# %%
d_arr.ndim
# Out:
# 3
